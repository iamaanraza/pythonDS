# %% [markdown]
# - bulit in functions
#    - input()
#    - print()
#    - isinstance()
#    - len()
#    - min()
#    - max()
#    - sum()
#    - abs()
#    - round()
#    - eval()
#    - all()
#    - any()
#    - open()

# %%
x = 129.05
isinstance(x,(int, float))
# Out:
# True

# %%
data = [1,2,3] 
isinstance(data, (list,set))
# Out:
# True

# %%
data = (1,2,3) #tuple hogya yeh
isinstance(data, (list,set))
# Out:
# False

# %%
abs(-10) # always return in +ve .
# Out:
# 10

# %%
a = 1.12345    #convert into whole no.
print(a)
print(round(a))
print(round(a,2))
print(round(a,5))
# Out:
# 1.12345
# 1
# 1.12
# 1.12345

# %%
x = 10 
y = 3
expression= input("Enter your equation using x and y:")
print("your equtaion is",expression)
print(eval(expression))
# Out:
# your equtaion is x+y+float(y)+1200
# 1216.0

# %%
eval('x*y')
# Out:
# 30

# %%
eval?
# Out:
# Signature: eval(source, globals=None, locals=None, /)
# Docstring:
# Evaluate the given source in the context of globals and locals.
#
# The source may be a string representing a Python expression
# or a code object as returned by compile().
# The globals must be a dictionary and locals can be any mapping,
# defaulting to the current globals and locals.
# If only globals is given, locals defaults to it.
# Type:      builtin_function_or_method

# %%
x = [1,2,3,4,5,6]
y = [1,2,3,4,5,0]
z = [0,0,0,0,0,0]
a = [0,0,0,0,0,1]

print(all(x)) # sari value +ve toh true 
print(all(y)) # sari value mein agar 0 hua toh false 
print(all(z)) # all value are false 
print(any(z)) # 
print(any(a))
print(any(x))
# Out:
# True
# False
# False
# False
# True
# True

# %%
print(bool(0), bool(''), bool('asd'), bool(-1), bool(120))
# Out:
# False False True True True

# %% [markdown]
# file handling with open()
#  - read
#  - write
#  - append

# %%
file = open('../dummy.txt') # relative path 
print(file)
# Out:
# <_io.TextIOWrapper name='../dummy.txt' mode='r' encoding='utf-8'>

# %%
file.read()
# Out:
# 'hello digipodium \n'

# %%
with open('../dummy.txt') as file:  #safe option
    print(file.read())
# Out:
# hello digipodium

# %%
with open('builtin.ipynb') as file:
    print(file.read())
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "- bulit in functions\n",
#     "   - input()\n",
#     "   - print()\n",
#     "   - isinstance()\n",
#     "   - len()\n",
#     "   - min()\n",
#     "   - max()\n",
#     "   - sum()\n",
#     "   - abs()\n",
#     "   - round()\n",
#     "   - eval()\n",
#     "   - all()\n",
#     "   - any()\n",
#     "   - open()"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 2,
#    "metadata": {},
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "True"
#       ]
#      },
#      "execution_count": 2,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "source": [
#     "x = 129.05\n",
#     "isinstance(x,(int, float))"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 3,
#    "metadata": {},
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "True"
#       ]
#      },
# ...

# %%
with open('builtin.ipynb') as file:
    print(file.read())
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "markdown",
#    "metadata": {},
#    "source": [
#     "- bulit in functions\n",
#     "   - input()\n",
#     "   - print()\n",
#     "   - isinstance()\n",
#     "   - len()\n",
#     "   - min()\n",
#     "   - max()\n",
#     "   - sum()\n",
#     "   - abs()\n",
#     "   - round()\n",
#     "   - eval()\n",
#     "   - all()\n",
#     "   - any()\n",
#     "   - open()"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 2,
#    "metadata": {},
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "True"
#       ]
#      },
#      "execution_count": 2,
#      "metadata": {},
#      "output_type": "execute_result"
#     }
#    ],
#    "source": [
#     "x = 129.05\n",
#     "isinstance(x,(int, float))"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 3,
#    "metadata": {},
#    "outputs": [
#     {
#      "data": {
#       "text/plain": [
#        "True"
#       ]
#      },
# ...

# %%
with open('../dummy.txt') as file :
    content = file.read()
print(content.split())
# Out:
# ['hello', 'digipodium']

# %%
path = r'C:\Users\user\Desktop\kuchbhi.txt'
with open(path) as f :
    print(f.read())
# Out:
# gwuqigwufyewio

# %%
x = [12,34,56,3,7,912,75,90]
print(max(x))
print(min(x))
print(sum(x))
# Out:
# 912
# 3
# 1189

# %%
meri_kahani = ''' once uopn a time 
there was a person 
to be continued...
'''
with open('kahani.txt', 'w') as f:
    f.write(meri_kahani)

# %%
dursi_kahani = '''ek samay ki baat hai,
bahut dur desh mein , ek pahad tha , jahan par baraf thi .
the end.
'''
addr = r"C:\Users\user\Desktop\dursi_kahani.txt"
with open(addr, 'w') as f:
    f.write(dursi_kahani)
    print("file saved✅")
# Out:
# file saved✅

# %%
user_ka_data = input("enter your story:")
with open(addr, 'a') as f:
    f.write("\n"+ user_ka_data)
    print("file saved✅")
# Out:
# file saved✅

# %%
with open(addr) as f :
    print(f.read())
# Out:
# ek samay ki baat hai,
# bahut dur desh mein , ek pahad tha , jahan par baraf thi .
# the end.
#
# im in ganj
